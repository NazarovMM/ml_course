# %% [markdown]
# ## Разведочный анализ данных. Исследование и визуализация данных.

# %% [markdown]
# ### 1)Текстовое описание набора данных

# %% [markdown]
# В качестве набора данных я использован данные о прогноз сердечной недостаточности - https://www.kaggle.com/andrewmvd/heart-failure-clinical-data

# %% [markdown]
# Описание набора данных с сайта: Сердечно-сосудистые заболевания (ССЗ) являются причиной смерти номер 1 во всем мире, ежегодно унося около 17,9 миллиона жизней, что составляет 31% всех смертей в мире. Сердечная недостаточность - частое явление, вызываемое сердечно-сосудистыми заболеваниями, и этот набор данных содержит 12 функций, которые можно использовать для прогнозирования смертности от сердечной недостаточности. Большинство сердечно-сосудистых заболеваний можно предотвратить путем устранения поведенческих факторов риска, таких как употребление табака, нездоровое питание и ожирение, недостаточная физическая активность и вредное употребление алкоголя, с использованием стратегий, охватывающих все население. Людям с сердечно-сосудистыми заболеваниями или с высоким риском сердечно-сосудистых заболеваний (из-за наличия одного или нескольких факторов риска, таких как гипертония, диабет, гиперлипидемия или уже установленное заболевание) необходимо раннее выявление и лечение, при этом модель машинного обучения может оказаться очень полезной.

# %% [markdown]
# #### Импорт библиотек

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
sns.set(style="ticks")

# %% [markdown]
# #### Загрузка данных

# %%
data = pd.read_csv('heart_failure_clinical_records_dataset.csv', sep=",")

# %% [markdown]
# ###  2)Основные характеристики датасета.

# %% [markdown]
# Первые 5 строчек датасета

# %%
data.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %% [markdown]
# Размер датасета - 299 строк и 13 столбцов

# %%
data.shape
# Out:
# (299, 13)

# %% [markdown]
# Список всех столбоц датасета

# %%
data.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %% [markdown]
# Список всез столбцов с их типами данных

# %%
data.dtypes
# Out:
# age                         float64
# anaemia                       int64
# creatinine_phosphokinase      int64
# diabetes                      int64
# ejection_fraction             int64
# high_blood_pressure           int64
# platelets                   float64
# serum_creatinine            float64
# serum_sodium                  int64
# sex                           int64
# smoking                       int64
# time                          int64
# DEATH_EVENT                   int64
# dtype: object

# %% [markdown]
# Проверка на наличие пустых ячеек в датасете - в данном датасете нет пустых значений

# %%
for col in data.columns:
    temp_null_count = data[data[col].isnull()].shape[0]
    print('{} - {}'.format(col, temp_null_count))
# Out:
# age - 0
# anaemia - 0
# creatinine_phosphokinase - 0
# diabetes - 0
# ejection_fraction - 0
# high_blood_pressure - 0
# platelets - 0
# serum_creatinine - 0
# serum_sodium - 0
# sex - 0
# smoking - 0
# time - 0
# DEATH_EVENT - 0

# %% [markdown]
# Основные статистические характеристики датасета

# %%
data.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# 25%            30.000000             0.000000  212500.000000
# 50%            38.000000             0.000000  262000.000000
# 75%            45.000000             1.000000  303500.000000
# max            80.000000             1.000000  850000.000000
#
#        serum_creatinine  serum_sodium         sex    smoking        time  \
# count         299.00000    299.000000  299.000000  299.00000  299.000000
# mean            1.39388    136.625418    0.648829    0.32107  130.260870
# std             1.03451      4.412477    0.478136    0.46767   77.614208
# min             0.50000    113.000000    0.000000    0.00000    4.000000
# 25%             0.90000    134.000000    0.000000    0.00000   73.000000
# 50%             1.10000    137.000000    1.000000    0.00000  115.000000
# 75%             1.40000    140.000000    1.000000    1.00000  203.000000
# max             9.40000    148.000000    1.000000    1.00000  285.000000
#
#        DEATH_EVENT
# count    299.00000
# mean       0.32107
# std        0.46767
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        1.00000
# max        1.00000

# %% [markdown]
# ###  3)Визуальное исследование датасета.

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.scatterplot(ax=ax, x='age', y='serum_sodium', data=data)
# Out:
# <AxesSubplot:xlabel='age', ylabel='serum_sodium'>

# %%
sns.pairplot(data)

# %%
sns.pairplot(data, hue="DEATH_EVENT")

# %%
sns.boxplot(x=data['age'])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.boxplot(x='DEATH_EVENT', y='age', data=data)
# Out:
# <AxesSubplot:xlabel='DEATH_EVENT', ylabel='age'>

# %%
sns.violinplot(x='DEATH_EVENT', y='age', data=data)
# Out:
# <AxesSubplot:xlabel='DEATH_EVENT', ylabel='age'>

# %%
import plotly.express as px
fig = px.histogram(dataset, x="age", color="DEATH_EVENT", marginal="violin",hover_data=dataset.columns,
                   title ="Distribution of Age Vs DEATH_EVENT", 
                   labels={"age": "AGE"})
fig.show()
# Out:
# <div>                            <div id="5dbbfbf8-5316-4e63-b07a-8252c0bbc927" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5dbbfbf8-5316-4e63-b07a-8252c0bbc927")) {                    Plotly.newPlot(                        "5dbbfbf8-5316-4e63-b07a-8252c0bbc927",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "DEATH_EVENT=1<br>AGE=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "1", "marker": {"color": "#636efa"}, "name": "1", "offsetgroup": "1", "orientation": "v", "showlegend": true, "type": "histogram", "x": [75.0, 55.0, 65.0, 50.0, 65.0, 90.0, 75.0, 60.0, 65.0, 80.0, 75.0, 62.0, 45.0, 50.0, 82.0, 87.0, 45.0, 70.0, 48.0, 65.0, 68.0, 75.0, 80.0, 95.0, 70.0, 58.0, 82.0, 94.0, 85.0, 50.0, 65.0, 69.0, 90.0, 82.0, 60.0, 70.0, 50.0, 70.0, 60.0, 50.0, 51.0, 60.0, 80.0, 57.0, 68.0, 53.0, 60.0, 70.0, 60.0, 95.0, 49.0, 72.0, 45.0, 50.0, 45.0, 60.0, 42.0, 72.0, 70.0, 65.0, 85.0, 69.0, 60.0, 60.0, 59.0, 60.0, 72.0, 85.0, 70.0, 86.0, 60.0, 46.0, 80.0, 72.0, 75.0, 72.0, 50.0, 45.0, 80.0, 59.0, 59.0, 65.0, 75.0, 58.0, 60.667, 50.0, 60.0, 45.0, 77.0, 48.0, 54.0, 73.0, 60.0, 55.0, 65.0, 55.0], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[0.0, 582.0, 0.0, 20.0, 1.0, 265000.0, 1.9, 130.0, 1.0, 0.0, 4.0, 1.0], [0.0, 7861.0, 0.0, 38.0, 0.0, 263358.03, 1.1, 136.0, 1.0, 0.0, 6.0, 1.0], [0.0, 146.0, 0.0, 20.0, 0.0, 162000.0, 1.3, 129.0, 1.0, 1.0, 7.0, 1.0], [1.0, 111.0, 0.0, 20.0, 0.0, 210000.0, 1.9, 137.0, 1.0, 0.0, 7.0, 1.0], [1.0, 160.0, 1.0, 20.0, 0.0, 327000.0, 2.7, 116.0, 0.0, 0.0, 8.0, 1.0], [1.0, 47.0, 0.0, 40.0, 1.0, 204000.0, 2.1, 132.0, 1.0, 1.0, 8.0, 1.0], [1.0, 246.0, 0.0, 15.0, 0.0, 127000.0, 1.2, 137.0, 1.0, 0.0, 10.0, 1.0], [1.0, 315.0, 1.0, 60.0, 0.0, 454000.0, 1.1, 131.0, 1.0, 1.0, 10.0, 1.0], [0.0, 157.0, 0.0, 65.0, 0.0, 263358.03, 1.5, 138.0, 0.0, 0.0, 10.0, 1.0], [1.0, 123.0, 0.0, 35.0, 1.0, 388000.0, 9.4, 133.0, 1.0, 1.0, 10.0, 1.0], [1.0, 81.0, 0.0, 38.0, 1.0, 368000.0, 4.0, 131.0, 1.0, 1.0, 10.0, 1.0], [0.0, 231.0, 0.0, 25.0, 1.0, 253000.0, 0.9, 140.0, 1.0, 1.0, 10.0, 1.0], [1.0, 981.0, 0.0, 30.0, 0.0, 136000.0, 1.1, 137.0, 1.0, 0.0, 11.0, 1.0], [1.0, 168.0, 0.0, 38.0, 1.0, 276000.0, 1.1, 137.0, 1.0, 0.0, 11.0, 1.0], [1.0, 379.0, 0.0, 50.0, 0.0, 47000.0, 1.3, 136.0, 1.0, 0.0, 13.0, 1.0], [1.0, 149.0, 0.0, 38.0, 0.0, 262000.0, 0.9, 140.0, 1.0, 0.0, 14.0, 1.0], [0.0, 582.0, 0.0, 14.0, 0.0, 166000.0, 0.8, 127.0, 1.0, 0.0, 14.0, 1.0], [1.0, 125.0, 0.0, 25.0, 1.0, 237000.0, 1.0, 140.0, 0.0, 0.0, 15.0, 1.0], [1.0, 582.0, 1.0, 55.0, 0.0, 87000.0, 1.9, 121.0, 0.0, 0.0, 15.0, 1.0], [1.0, 128.0, 1.0, 30.0, 1.0, 297000.0, 1.6, 136.0, 0.0, 0.0, 20.0, 1.0], [1.0, 220.0, 0.0, 35.0, 1.0, 289000.0, 0.9, 140.0, 1.0, 1.0, 20.0, 1.0], [0.0, 582.0, 1.0, 30.0, 1.0, 263358.03, 1.83, 134.0, 0.0, 0.0, 23.0, 1.0], [0.0, 148.0, 1.0, 38.0, 0.0, 149000.0, 1.9, 144.0, 1.0, 1.0, 23.0, 1.0], [1.0, 112.0, 0.0, 40.0, 1.0, 196000.0, 1.0, 138.0, 0.0, 0.0, 24.0, 1.0], [0.0, 122.0, 1.0, 45.0, 1.0, 284000.0, 1.3, 136.0, 1.0, 1.0, 26.0, 1.0], [1.0, 60.0, 0.0, 38.0, 0.0, 153000.0, 5.8, 134.0, 1.0, 0.0, 26.0, 1.0], [0.0, 70.0, 1.0, 30.0, 0.0, 200000.0, 1.2, 132.0, 1.0, 1.0, 26.0, 1.0], [0.0, 582.0, 1.0, 38.0, 1.0, 263358.03, 1.83, 134.0, 1.0, 0.0, 27.0, 1.0], [0.0, 23.0, 0.0, 45.0, 0.0, 360000.0, 3.0, 132.0, 1.0, 0.0, 28.0, 1.0], [1.0, 249.0, 1.0, 35.0, 1.0, 319000.0, 1.0, 128.0, 0.0, 0.0, 28.0, 1.0], [0.0, 94.0, 1.0, 50.0, 1.0, 188000.0, 1.0, 140.0, 1.0, 0.0, 29.0, 1.0], [0.0, 582.0, 1.0, 35.0, 0.0, 228000.0, 3.5, 134.0, 1.0, 0.0, 30.0, 1.0], [1.0, 60.0, 1.0, 50.0, 0.0, 226000.0, 1.0, 134.0, 1.0, 0.0, 30.0, 1.0], [1.0, 855.0, 1.0, 50.0, 1.0, 321000.0, 1.0, 145.0, 0.0, 0.0, 30.0, 1.0], [0.0, 235.0, 1.0, 38.0, 0.0, 329000.0, 3.0, 142.0, 0.0, 0.0, 30.0, 1.0], [ ...

# %% [markdown]
# ###  4)Информация о корреляции признаков.

# %%
data.corr()
# Out:
#                                age   anaemia  creatinine_phosphokinase  \
# age                       1.000000  0.088006                 -0.081584
# anaemia                   0.088006  1.000000                 -0.190741
# creatinine_phosphokinase -0.081584 -0.190741                  1.000000
# diabetes                 -0.101012 -0.012729                 -0.009639
# ejection_fraction         0.060098  0.031557                 -0.044080
# high_blood_pressure       0.093289  0.038182                 -0.070590
# platelets                -0.052354 -0.043786                  0.024463
# serum_creatinine          0.159187  0.052174                 -0.016408
# serum_sodium             -0.045966  0.041882                  0.059550
# sex                       0.065430 -0.094769                  0.079791
# smoking                   0.018668 -0.107290                  0.002421
# time                     -0.224068 -0.141414                 -0.009346
# DEATH_EVENT               0.253729  0.066270                  0.062728
#
#                           diabetes  ejection_fraction  high_blood_pressure  \
# age                      -0.101012           0.060098             0.093289
# anaemia                  -0.012729           0.031557             0.038182
# creatinine_phosphokinase -0.009639          -0.044080            -0.070590
# diabetes                  1.000000          -0.004850            -0.012732
# ejection_fraction        -0.004850           1.000000             0.024445
# high_blood_pressure      -0.012732           0.024445             1.000000
# platelets                 0.092193           0.072177             0.049963
# serum_creatinine         -0.046975          -0.011302            -0.004935
# serum_sodium             -0.089551           0.175902             0.037109
# sex                      -0.157730          -0.148386            -0.104615
# smoking                  -0.147173          -0.067315            -0.055711
# time                      0.033726           0.041729            -0.196439
# DEATH_EVENT              -0.001943          -0.268603             0.079351
#
#                           platelets  serum_creatinine  serum_sodium       sex  \
# age                       -0.052354          0.159187     -0.045966  0.065430
# anaemia                   -0.043786          0.052174      0.041882 -0.094769
# creatinine_phosphokinase   0.024463         -0.016408      0.059550  0.079791
# diabetes                   0.092193         -0.046975     -0.089551 -0.157730
# ejection_fraction          0.072177         -0.011302      0.175902 -0.148386
# high_blood_pressure        0.049963         -0.004935      0.037109 -0.104615
# platelets                  1.000000         -0.041198      0.062125 -0.125120
# serum_creatinine          -0.041198          1.000000     -0.189095  0.006970
# serum_sodium               0.062125         -0.189095      1.000000 -0.027566
# sex                       -0.125120          0.006970     -0.027566  1.000000
# smoking                    0.028234         -0.027414      0.004813  0.445892
# time                       0.010514         -0.149315      0.087640 -0.015608
# DEATH_EVENT               -0.049139          0.294278     -0.195204 -0.004316
#
#                            smoking      time  DEATH_EVENT
# age                       0.018668 -0.224068     0.253729
# anaemia                  -0.107290 -0.141414     0.066270
# creatinine_phosphokinase  0.002421 -0.009346     0.062728
# diabetes                 -0.147173  0.033726    -0.001943
# ejection_fraction        -0.067315  0.041729    -0.268603
# high_blood_pressure      -0.055711 -0.196439     0.079351
# platelets                 0.028234  0.010514    -0.049139
# serum_creatinine         -0.027414 -0.149315     0.294278
# serum_sodium              0.004813  0.087640    -0.195204
# sex                       0.445892 -0.015608    -0.004316
# smoking                   1.000000 -0.022839    -0.012623
# time                     -0.022839  1.000000    -0.526964
# DEATH_EVENT              -0.012623 -0.526964     1.000000

# %%
data.corr(method='pearson')
# Out:
#                                age   anaemia  creatinine_phosphokinase  \
# age                       1.000000  0.088006                 -0.081584
# anaemia                   0.088006  1.000000                 -0.190741
# creatinine_phosphokinase -0.081584 -0.190741                  1.000000
# diabetes                 -0.101012 -0.012729                 -0.009639
# ejection_fraction         0.060098  0.031557                 -0.044080
# high_blood_pressure       0.093289  0.038182                 -0.070590
# platelets                -0.052354 -0.043786                  0.024463
# serum_creatinine          0.159187  0.052174                 -0.016408
# serum_sodium             -0.045966  0.041882                  0.059550
# sex                       0.065430 -0.094769                  0.079791
# smoking                   0.018668 -0.107290                  0.002421
# time                     -0.224068 -0.141414                 -0.009346
# DEATH_EVENT               0.253729  0.066270                  0.062728
#
#                           diabetes  ejection_fraction  high_blood_pressure  \
# age                      -0.101012           0.060098             0.093289
# anaemia                  -0.012729           0.031557             0.038182
# creatinine_phosphokinase -0.009639          -0.044080            -0.070590
# diabetes                  1.000000          -0.004850            -0.012732
# ejection_fraction        -0.004850           1.000000             0.024445
# high_blood_pressure      -0.012732           0.024445             1.000000
# platelets                 0.092193           0.072177             0.049963
# serum_creatinine         -0.046975          -0.011302            -0.004935
# serum_sodium             -0.089551           0.175902             0.037109
# sex                      -0.157730          -0.148386            -0.104615
# smoking                  -0.147173          -0.067315            -0.055711
# time                      0.033726           0.041729            -0.196439
# DEATH_EVENT              -0.001943          -0.268603             0.079351
#
#                           platelets  serum_creatinine  serum_sodium       sex  \
# age                       -0.052354          0.159187     -0.045966  0.065430
# anaemia                   -0.043786          0.052174      0.041882 -0.094769
# creatinine_phosphokinase   0.024463         -0.016408      0.059550  0.079791
# diabetes                   0.092193         -0.046975     -0.089551 -0.157730
# ejection_fraction          0.072177         -0.011302      0.175902 -0.148386
# high_blood_pressure        0.049963         -0.004935      0.037109 -0.104615
# platelets                  1.000000         -0.041198      0.062125 -0.125120
# serum_creatinine          -0.041198          1.000000     -0.189095  0.006970
# serum_sodium               0.062125         -0.189095      1.000000 -0.027566
# sex                       -0.125120          0.006970     -0.027566  1.000000
# smoking                    0.028234         -0.027414      0.004813  0.445892
# time                       0.010514         -0.149315      0.087640 -0.015608
# DEATH_EVENT               -0.049139          0.294278     -0.195204 -0.004316
#
#                            smoking      time  DEATH_EVENT
# age                       0.018668 -0.224068     0.253729
# anaemia                  -0.107290 -0.141414     0.066270
# creatinine_phosphokinase  0.002421 -0.009346     0.062728
# diabetes                 -0.147173  0.033726    -0.001943
# ejection_fraction        -0.067315  0.041729    -0.268603
# high_blood_pressure      -0.055711 -0.196439     0.079351
# platelets                 0.028234  0.010514    -0.049139
# serum_creatinine         -0.027414 -0.149315     0.294278
# serum_sodium              0.004813  0.087640    -0.195204
# sex                       0.445892 -0.015608    -0.004316
# smoking                   1.000000 -0.022839    -0.012623
# time                     -0.022839  1.000000    -0.526964
# DEATH_EVENT              -0.012623 -0.526964     1.000000

# %%
data.corr(method='kendall')
# Out:
#                                age   anaemia  creatinine_phosphokinase  \
# age                       1.000000  0.060190                 -0.063180
# anaemia                   0.060190  1.000000                 -0.178712
# creatinine_phosphokinase -0.063180 -0.178712                  1.000000
# diabetes                 -0.075029 -0.012729                  0.034985
# ejection_fraction         0.051284  0.017519                 -0.047061
# high_blood_pressure       0.088488  0.038182                 -0.066753
# platelets                -0.037190 -0.029259                  0.039742
# serum_creatinine          0.190089 -0.013774                 -0.035139
# serum_sodium             -0.073368  0.052115                  0.013129
# sex                       0.048362 -0.094769                  0.010997
# smoking                   0.025227 -0.107290                 -0.025098
# time                     -0.136660 -0.110498                  0.083444
# DEATH_EVENT               0.182536  0.066270                  0.019529
#
#                           diabetes  ejection_fraction  high_blood_pressure  \
# age                      -0.075029           0.051284             0.088488
# anaemia                  -0.012729           0.017519             0.038182
# creatinine_phosphokinase  0.034985          -0.047061            -0.066753
# diabetes                  1.000000          -0.010242            -0.012732
# ejection_fraction        -0.010242           1.000000             0.015435
# high_blood_pressure      -0.012732           0.015435             1.000000
# platelets                 0.060665           0.037870             0.056715
# serum_creatinine          0.001637          -0.129745            -0.075944
# serum_sodium             -0.047007           0.118261             0.016364
# sex                      -0.157730          -0.112508            -0.104615
# smoking                  -0.147173          -0.061718            -0.055711
# time                      0.024209           0.050908            -0.159852
# DEATH_EVENT              -0.001943          -0.246766             0.079351
#
#                           platelets  serum_creatinine  serum_sodium       sex  \
# age                       -0.037190          0.190089     -0.073368  0.048362
# anaemia                   -0.029259         -0.013774      0.052115 -0.094769
# creatinine_phosphokinase   0.039742         -0.035139      0.013129  0.010997
# diabetes                   0.060665          0.001637     -0.047007 -0.157730
# ejection_fraction          0.037870         -0.129745      0.118261 -0.112508
# high_blood_pressure        0.056715         -0.075944      0.016364 -0.104615
# platelets                  1.000000         -0.035681      0.034561 -0.112929
# serum_creatinine          -0.035681          1.000000     -0.223007  0.044186
# serum_sodium               0.034561         -0.223007      1.000000 -0.065421
# sex                       -0.112929          0.044186     -0.065421  1.000000
# smoking                    0.003922         -0.014435      0.007074  0.445892
# time                      -0.004369         -0.109593      0.059389 -0.014223
# DEATH_EVENT               -0.037962          0.313822     -0.178090 -0.004316
#
#                            smoking      time  DEATH_EVENT
# age                       0.025227 -0.136660     0.182536
# anaemia                  -0.107290 -0.110498     0.066270
# creatinine_phosphokinase -0.025098  0.083444     0.019529
# diabetes                 -0.147173  0.024209    -0.001943
# ejection_fraction        -0.061718  0.050908    -0.246766
# high_blood_pressure      -0.055711 -0.159852     0.079351
# platelets                 0.003922 -0.004369    -0.037962
# serum_creatinine         -0.014435 -0.109593     0.313822
# serum_sodium              0.007074  0.059389    -0.178090
# sex                       0.445892 -0.014223    -0.004316
# smoking                   1.000000 -0.021727    -0.012623
# time                     -0.021727  1.000000    -0.445744
# DEATH_EVENT              -0.012623 -0.445744     1.000000

# %%
data.corr(method='spearman')
# Out:
#                                age   anaemia  creatinine_phosphokinase  \
# age                       1.000000  0.071924                 -0.093078
# anaemia                   0.071924  1.000000                 -0.216116
# creatinine_phosphokinase -0.093078 -0.216116                  1.000000
# diabetes                 -0.089657 -0.012729                  0.042308
# ejection_fraction         0.074047  0.020366                 -0.067839
# high_blood_pressure       0.105740  0.038182                 -0.080724
# platelets                -0.052091 -0.035608                  0.060033
# serum_creatinine          0.270561 -0.016267                 -0.049936
# serum_sodium             -0.101716  0.061405                  0.016886
# sex                       0.057791 -0.094769                  0.013298
# smoking                   0.030145 -0.107290                 -0.030351
# time                     -0.197524 -0.134652                  0.125823
# DEATH_EVENT               0.218125  0.066270                  0.023616
#
#                           diabetes  ejection_fraction  high_blood_pressure  \
# age                      -0.089657           0.074047             0.105740
# anaemia                  -0.012729           0.020366             0.038182
# creatinine_phosphokinase  0.042308          -0.067839            -0.080724
# diabetes                  1.000000          -0.011906            -0.012732
# ejection_fraction        -0.011906           1.000000             0.017943
# high_blood_pressure      -0.012732           0.017943             1.000000
# platelets                 0.073829           0.053696             0.069021
# serum_creatinine          0.001933          -0.177986            -0.089692
# serum_sodium             -0.055386           0.161695             0.019281
# sex                      -0.157730          -0.130792            -0.104615
# smoking                  -0.147173          -0.071748            -0.055711
# time                      0.029501           0.070533            -0.194794
# DEATH_EVENT              -0.001943          -0.286869             0.079351
#
#                           platelets  serum_creatinine  serum_sodium       sex  \
# age                       -0.052091          0.270561     -0.101716  0.057791
# anaemia                   -0.035608         -0.016267      0.061405 -0.094769
# creatinine_phosphokinase   0.060033         -0.049936      0.016886  0.013298
# diabetes                   0.073829          0.001933     -0.055386 -0.157730
# ejection_fraction          0.053696         -0.177986      0.161695 -0.130792
# high_blood_pressure        0.069021         -0.089692      0.019281 -0.104615
# platelets                  1.000000         -0.051028      0.049453 -0.137433
# serum_creatinine          -0.051028          1.000000     -0.300413  0.052184
# serum_sodium               0.049453         -0.300413      1.000000 -0.077084
# sex                       -0.137433          0.052184     -0.077084  1.000000
# smoking                    0.004774         -0.017048      0.008335  0.445892
# time                      -0.006927         -0.160990      0.086393 -0.017332
# DEATH_EVENT               -0.046200          0.370630     -0.209837 -0.004316
#
#                            smoking      time  DEATH_EVENT
# age                       0.030145 -0.197524     0.218125
# anaemia                  -0.107290 -0.134652     0.066270
# creatinine_phosphokinase -0.030351  0.125823     0.023616
# diabetes                 -0.147173  0.029501    -0.001943
# ejection_fraction        -0.071748  0.070533    -0.286869
# high_blood_pressure      -0.055711 -0.194794     0.079351
# platelets                 0.004774 -0.006927    -0.046200
# serum_creatinine         -0.017048 -0.160990     0.370630
# serum_sodium              0.008335  0.086393    -0.209837
# sex                       0.445892 -0.017332    -0.004316
# smoking                   1.000000 -0.026476    -0.012623
# time                     -0.026476  1.000000    -0.543179
# DEATH_EVENT              -0.012623 -0.543179     1.000000

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(1, 3, sharex='col', sharey='row', figsize=(15,5))
sns.heatmap(data.corr(method='pearson'), ax=ax[0])
sns.heatmap(data.corr(method='kendall'), ax=ax[1])
sns.heatmap(data.corr(method='spearman'), ax=ax[2])
fig.suptitle('Корреляционные матрицы, построенные различными методами')
ax[0].title.set_text('Pearson')
ax[1].title.set_text('Kendall')
ax[2].title.set_text('Spearman')
